# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a new set of 2,000 random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Get the nearest city using the citipy module
from citipy import citipy

coordinates = list(lat_lngs)

# %%
# Create a list for cities.
cities = []
# Identify latitude and longitude combination the nearest cities.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

# If city is not present ad to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count 
len(cities)
# Out:
# 756

# %%
# Import the requests.
import requests

# Import the API key.
from config import api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create counters.
record_count = 1
set_count = 1

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

# Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
# Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

# Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
# Add 1 to the record count.
    record_count += 1       
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                              "Country": city_country,
                              "Lat": city_lat,
                              "Lng": city_lng,
                              "Max Temp": city_max_temp,
                              "Humidity": city_humidity,
                              "Cloudiness": city_clouds,
                              "Wind Speed": city_wind,
                              "Current Description": city_weather_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | cape town
# Processing Record 2 of Set 1 | castro
# Processing Record 3 of Set 1 | hobart
# Processing Record 4 of Set 1 | rantepao
# Processing Record 5 of Set 1 | alice springs
# Processing Record 6 of Set 1 | chapais
# Processing Record 7 of Set 1 | santa rosa
# Processing Record 8 of Set 1 | hilo
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | cabo san lucas
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | bluff
# Processing Record 13 of Set 1 | new norfolk
# Processing Record 14 of Set 1 | jamestown
# Processing Record 15 of Set 1 | cidreira
# Processing Record 16 of Set 1 | barrow
# Processing Record 17 of Set 1 | rincon
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | dunedin
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | hermanus
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 1 | ewa beach
# Processing Record 26 of Set 1 | port elizabeth
# Processing Record 27 of Set 1 | tura
# Processing Record 28 of Set 1 | puerto ayora
# Processing Record 29 of Set 1 | sandusky
# Processing Record 30 of Set 1 | joshimath
# Processing Record 31 of Set 1 | khatanga
# Processing Record 32 of Set 1 | kuopio
# Processing Record 33 of Set 1 | luwingu
# Processing Record 34 of Set 1 | rocha
# Processing Record 35 of Set 1 | ilulissat
# Processing Record 36 of Set 1 | sabzevar
# Processing Record 37 of Set 1 | east london
# Processing Record 38 of Set 1 | sao joao da barra
# Processing Record 39 of Set 1 | ngukurr
# City not found. Skipping...
# Processing Record 40 of Set 1 | aykhal
# Processing Record 41 of Set 1 | butaritari
# Processing Record 42 of Set 1 | warrnambool
# Processing Record 43 of Set 1 | vestmannaeyjar
# Processing Record 44 of Set 1 | tessalit
# Processing Record 45 of Set 1 | thompson
# Processing Record 46 of Set 1 | kasongo
# Processing Record 47 of Set 1 | hobyo
# Processing Record 48 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 1 | san patricio
# Processing Record 50 of Set 1 | sedro-woolley
# Processing Record 1 of Set 2 | georgetown
# Processing Record 2 of Set 2 | mirnyy
# Processing Record 3 of Set 2 | sedalia
# Processing Record 4 of Set 2 | sri aman
# Processing Record 5 of Set 2 | saint-francois
# Processing Record 6 of Set 2 | utete
# Processing Record 7 of Set 2 | krzeszowice
# Processing Record 8 of Set 2 | concarneau
# Processing Record 9 of Set 2 | ribeira grande
# Processing Record 10 of Set 2 | preston
# Processing Record 11 of Set 2 | punta arenas
# Processing Record 12 of Set 2 | atuona
# Processing Record 13 of Set 2 | zavyalovo
# Processing Record 14 of Set 2 | vardo
# Processing Record 15 of Set 2 | dolbeau
# City not found. Skipping...
# Processing Record 16 of Set 2 | severo-kurilsk
# Processing Record 17 of Set 2 | turayf
# Processing Record 18 of Set 2 | guerrero negro
# Processing Record 19 of Set 2 | srednekolymsk
# Processing Record 20 of Set 2 | bambous virieux
# Processing Record 21 of Set 2 | saint-philippe
# Processing Record 22 of Set 2 | puerto colombia
# Processing Record 23 of Set 2 | avarua
# Processing Record 24 of Set 2 | vaini
# Processing Record 25 of Set 2 | sitka
# Processing Record 26 of Set 2 | mokhsogollokh
# Processing Record 27 of Set 2 | port hedland
# Processing Record 28 of Set 2 | seddon
# Processing Record 29 of Set 2 | luz
# Processing Record 30 of Set 2 | morondava
# Processing Record 31 of Set 2 | acapulco
# Processing Record 32 of Set 2 | los algarrobos
# Processing Record 33 of Set 2 | beipiao
# Processing Record 34 of Set 2 | college
# Processing Record 35 of Set 2 | la ronge
# Processing Record 36 of Set 2 | kalengwa
# Processing Record 37 of Set 2 | guelengdeng
# City not found. Skipping...
# Processing Record 38 of Set 2 | shiyan
# Processing Record 39 of Set 2 | samarai
# Processing Record 40 of Set 2 | taltal
# Processing Record 41 of Set 2 | olinda
# Processing Record 42 of Set 2 | saskylakh
# Processing Record 43 of Set 2 | upernavik
# Processing Record 44 of Set 2 | torbay
# Processing Record 45 of Set 2 | norman wells
# Processing Record 46 of Set 2 | nikolskoye
# Processing Record 47 of Set 2 | lasem
# Processing Record 48 of Set 2 | victoria
# Processing Record 49 of Set 2 | saint george
# Processing Record 50 of Set 2 | husavik
# Processing Record 1 of Set 3 | lady lake
# Processing Record 2 of Set 3 | xucheng
# Processing Record 3 of Set 3 | porto tolle
# Processing Record 4 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 3 | mashhad
# Processing Record 6 of Set 3 | ilhabela
# Processing Record 7 of Set 3 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 8 of Set 3 | faanui
# Processing Record 9 of Set 3 | korla
# Processing Record 10 of Set 3 | abu samrah
# Processing Record 11 of Set 3 | matara
# Processing Record 12 of Set 3 | carnarvon
# Processing Record 13 of Set 3 | saldanha
# Processing Record 14 of Set 3 | dikson
# Processing Record 15 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 3 | halmstad
# Processing Record 18 of Set 3 | jinchang
# Processing Record 19 of Set 3 | bubaque
# Processing Record 20 of Set 3 | kodiak
# Processing Record 21 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 3 | provideniya
# Processing Record 23 of Set 3 | tual
# Processing Record 24 of Set 3 | port alfred
# Processing Record 25 of Set 3 | bredasdorp
# Processing Record 26 of Set 3 | vao
# Processing Record 27 of Set 3 | ahuimanu
# Processing Record 28 of Set 3 | boo
# Processing Record 29 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 3 | jacareacanga
# Processing Record 31 of Set 3 | kapaa
# Processing Record 32 of Set 3 | ancud
# Processing Record 33 of Set 3 | half moon bay
# Processing Record 34 of Set 3 | hasaki
# Processing Record 35 of Set 3 | adrar
# Processing Record 36 of Set 3 | qaanaaq
# Processing Record 37 of Set 3 | kaeo
# Processing Record 38 of Set 3 | linxia
# Processing Record 39 of Set 3 | coquimbo
# Processing Record 40 of Set 3 | kavaratti
# Processing Record 41 of Set 3 | lasa
# Processing Record 42 of Set 3 | baishishan
# Processing Record 43 of Set 3 | geraldton
# Processing Record 44 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 3 | itoman
# Processing Record 46 of Set 3 | cherskiy
# Processing Record 47 of Set 3 | kodino
# Processing Record 48 of Set 3 | sukhobuzimskoye
# Processing Record 49 of Set 3 | santa cruz
# Processing Record 50 of Set 3 | christchurch
# Processing Record 1 of Set 4 | vila franca do campo
# Processing Record 2 of Set 4 | kampot
# Processing Record 3 of Set 4 | sao filipe
# Processing Record 4 of Set 4 | mehran
# Processing Record 5 of Set 4 | halifax
# Processing Record 6 of Set 4 | salta
# Processing Record 7 of Set 4 | hami
# Processing Record 8 of Set 4 | chokurdakh
# Processing Record 9 of Set 4 | hermosillo
# Processing Record 10 of Set 4 | haines junction
# Processing Record 11 of Set 4 | dwarka
# Processing Record 12 of Set 4 | port hardy
# Processing Record 13 of Set 4 | longyearbyen
# Processing Record 14 of Set 4 | clyde river
# Processing Record 15 of Set 4 | lagoa
# Processing Record 16 of Set 4 | burica
# City not found. Skipping...
# Processing Record 17 of Set 4 | batemans bay
# Processing Record 18 of Set 4 | lima
# Processing Record 19 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 4 | vargem grande do sul
# Processing Record 21 of Set 4 | mogok
# Processing Record 22 of Set 4 | necochea
# Processing Record 23 of Set 4 | richards bay
# Processing Record 24 of Set 4 | mount gambier
# Processing Record 25 of Set 4 | mayo
# Processing Record 26 of Set 4 | latung
# Processing Record 27 of Set 4 | jiuquan
# Processing Record 28 of Set 4 | chegutu
# Processing Record 29 of Set 4 | nainpur
# Processing Record 30 of Set 4 | chuy
# Processing Record 31 of Set 4 | juybar
# Processing Record 32 of Set 4 | khartoum
# Processing Record 33 of Set 4 | de aar
# Processing Record 34 of Set 4 | poso
# Processing Record 35 of Set 4 | shimoda
# Processing Record 36 of Set 4 | lorengau
# Processing Record 37 of Set 4 | salalah
# Processing Record 38 of Set 4 | rawson
# Processing Record 39 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 4 | shelbyville
# Processing Record 41 of Set 4 | magistralnyy
# Processing Record 42 of Set 4 | tautira
# Processing Record 43 of Set 4 | lodja
# Processing Record 44 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 4 | corn island
# Processing Record 46 of Set 4 | kavieng
# Processing Record 47 of Set 4 | iqaluit
# Processing Record 48 of Set 4 | tungor
# Processing Record 49 of Set 4 | nishihara
# Processing Record 50 of Set 4 | bengkulu
# Processing Record 1 of Set 5 | kailua
# Processing Record 2 of Set 5 | dudinka
# Processing Record 3 of Set 5 | concepcion del oro
# Processing Record 4 of Set 5 | pacific grove
# Processing Record 5 of Set 5 | hovd
# Processing Record 6 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 5 | troitskoye
# Processing Record 8 of Set 5 | tierralta
# Processing Record 9 of Set 5 | tzaneen
# Processing Record 10 of Set 5 | tuatapere
# Processing Record 11 of Set 5 | seoul
# Processing Record 12 of Set 5 | atar
# Processing Record 13 of Set 5 | atascadero
# Processing Record 14 of Set 5 | maniitsoq
# Processing Record 15 of Set 5 | broken hill
# Processing Record 16 of Set 5 | sosnovo-ozerskoye
# Processing Record 17 of Set 5 | malpe
# Processing Record 18 of Set 5 | gomel
# Processing Record 19 of Set 5 | trelleborg
# Processing Record 20 of Set 5 | mandurah
# Processing Record 21 of Set 5 | mancio lima
# Processing Record 22 of Set 5 | arraial do cabo
# Processing Record 23 of Set 5 | nome
# Processing Record 24 of Set 5 | buala
# Processing Record 25 of Set 5 | sisimiut
# Processing Record 26 of Set 5 | amapa
# Processing Record 27 of Set 5 | pokhara
# Processing Record 28 of Set 5 | tuktoyaktuk
# Processing Record 29 of Set 5 | tiksi
# Processing Record 30 of Set 5 | ingham
# Processing Record 31 of Set 5 | axim
# Processing Record 32 of Set 5 | shenjiamen
# Processing Record 33 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 34 of Set 5 | bay city
# Processing Record 35 of Set 5 | aklavik
# Processing Record 36 of Set 5 | sur
# Processing Record 37 of Set 5 | iwanai
# Processing Record 38 of Set 5 | bosaso
# Processing Record 39 of Set 5 | baoqing
# Processing Record 40 of Set 5 | tilichiki
# Processing Record 41 of Set 5 | tchollire
# Processing Record 42 of Set 5 | kyaikkami
# Processing Record 43 of Set 5 | cap-aux-meules
# Processing Record 44 of Set 5 | migori
# Processing Record 45 of Set 5 | kahului
# Processing Record 46 of Set 5 | narsaq
# Processing Record 47 of Set 5 | zhigansk
# Processing Record 48 of Set 5 | pevek
# Processing Record 49 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 50 of Set 5 | ostrovnoy
# Processing Record 1 of Set 6 | nantucket
# Processing Record 2 of Set 6 | laguna
# Processing Record 3 of Set 6 | yinchuan
# Processing Record 4 of Set 6 | isangel
# Processing Record 5 of Set 6 | norilsk
# Processing Record 6 of Set 6 | yellowknife
# Processing Record 7 of Set 6 | caravelas
# Processing Record 8 of Set 6 | tasiilaq
# Processing Record 9 of Set 6 | kawhia
# Processing Record 10 of Set 6 | talnakh
# Processing Record 11 of Set 6 | shakawe
# Processing Record 12 of Set 6 | jumla
# Processing Record 13 of Set 6 | ust-kuyga
# Processing Record 14 of Set 6 | namibe
# Processing Record 15 of Set 6 | namwala
# Processing Record 16 of Set 6 | sorong
# Processing Record 17 of Set 6 | katsuura
# Processing Record 18 of Set 6 | port lincoln
# Processing Record 19 of Set 6 | canon city
# Processing Record 20 of Set 6 | port-gentil
# Processing Record 21 of Set 6 | catuday
# Processing Record 22 of Set 6 | havelock
# Processing Record 23 of Set 6 | roald
# Processing Record 24 of Set 6 | zyryanskoye
# Processing Record 25 of Set 6 | champerico
# Processing Record 26 of Set 6 | bethel
# Processing Record 27 of Set 6 | kotido
# Processing Record 28 of Set 6 | marshall
# Processing Record 29 of Set 6 | gazojak
# Processing Record 30 of Set 6 | tazovskiy
# Processing Record 31 of Set 6 | sabha
# Processing Record 32 of Set 6 | guiratinga
# Processing Record 33 of Set 6 | verkhnevilyuysk
# Processing Record 34 of Set 6 | kuytun
# Processing Record 35 of Set 6 | hervey bay
# Processing Record 36 of Set 6 | upata
# Processing Record 37 of Set 6 | turkan
# Processing Record 38 of Set 6 | yumen
# Processing Record 39 of Set 6 | antofagasta
# Processing Record 40 of Set 6 | ust-kut
# Processing Record 41 of Set 6 | dongsheng
# Processing Record 42 of Set 6 | akcakoca
# Processing Record 43 of Set 6 | yulara
# Processing Record 44 of Set 6 | ishigaki
# Processing Record 45 of Set 6 | parrita
# Processing Record 46 of Set 6 | castrillon
# Processing Record 47 of Set 6 | mandera
# Processing Record 48 of Set 6 | kormend
# Processing Record 49 of Set 6 | inhambane
# Processing Record 50 of Set 6 | vostok
# Processing Record 1 of Set 7 | ambunti
# Processing Record 2 of Set 7 | tanete
# Processing Record 3 of Set 7 | long
# Processing Record 4 of Set 7 | dhidhdhoo
# Processing Record 5 of Set 7 | amahai
# Processing Record 6 of Set 7 | santarem
# Processing Record 7 of Set 7 | bac lieu
# Processing Record 8 of Set 7 | mar del plata
# Processing Record 9 of Set 7 | ahipara
# Processing Record 10 of Set 7 | beringovskiy
# Processing Record 11 of Set 7 | talaya
# Processing Record 12 of Set 7 | estacion coahuila
# Processing Record 13 of Set 7 | le port
# Processing Record 14 of Set 7 | fortuna
# Processing Record 15 of Set 7 | los llanos de aridane
# Processing Record 16 of Set 7 | caborca
# Processing Record 17 of Set 7 | sungaipenuh
# Processing Record 18 of Set 7 | opuwo
# Processing Record 19 of Set 7 | vagur
# Processing Record 20 of Set 7 | kangaatsiaq
# Processing Record 21 of Set 7 | codrington
# Processing Record 22 of Set 7 | cedar city
# Processing Record 23 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 7 | timmins
# Processing Record 25 of Set 7 | gatesville
# Processing Record 26 of Set 7 | xuchang
# Processing Record 27 of Set 7 | harper
# Processing Record 28 of Set 7 | itarema
# Processing Record 29 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 30 of Set 7 | saint-augustin
# Processing Record 31 of Set 7 | rapar
# Processing Record 32 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 33 of Set 7 | aybak
# City not found. Skipping...
# Processing Record 34 of Set 7 | chilca
# Processing Record 35 of Set 7 | ponta do sol
# Processing Record 36 of Set 7 | dandong
# Processing Record 37 of Set 7 | ust-barguzin
# Processing Record 38 of Set 7 | utrecht
# Processing Record 39 of Set 7 | irpa irpa
# Processing Record 40 of Set 7 | chaihe
# Processing Record 41 of Set 7 | kaitangata
# Processing Record 42 of Set 7 | northam
# Processing Record 43 of Set 7 | korgen
# Processing Record 44 of Set 7 | tigil
# Processing Record 45 of Set 7 | nemuro
# Processing Record 46 of Set 7 | solovetskiy
# City not found. Skipping...
# Processing Record 47 of Set 7 | elko
# Processing Record 48 of Set 7 | lichuan
# Processing Record 49 of Set 7 | papetoai
# Processing Record 50 of Set 7 | aksu
# Processing Record 1 of Set 8 | matipo
# Processing Record 2 of Set 8 | broome
# Processing Record 3 of Set 8 | el faiyum
# City not found. Skipping...
# Processing Record 4 of Set 8 | rodrigues alves
# Processing Record 5 of Set 8 | kutum
# Processing Record 6 of Set 8 | airai
# Processing Record 7 of Set 8 | peachland
# Processing Record 8 of Set 8 | kahuta
# Processing Record 9 of Set 8 | manaure
# Processing Record 10 of Set 8 | wanning
# Processing Record 11 of Set 8 | eureka
# Processing Record 12 of Set 8 | vaghodia
# Processing Record 13 of Set 8 | kommunar
# Processing Record 14 of Set 8 | stettler
# Processing Record 15 of Set 8 | huarmey
# Processing Record 16 of Set 8 | chastoozerye
# City not found. Skipping...
# Processing Record 17 of Set 8 | sept-iles
# Processing Record 18 of Set 8 | danshui
# Processing Record 19 of Set 8 | yeppoon
# Processing Record 20 of Set 8 | rio gallegos
# Processing Record 21 of Set 8 | hato mayor
# Processing Record 22 of Set 8 | atikokan
# Processing Record 23 of Set 8 | luderitz
# Processing Record 24 of Set 8 | aswan
# Processing Record 25 of Set 8 | carlyle
# Processing Record 26 of Set 8 | lompoc
# Processing Record 27 of Set 8 | igra
# Processing Record 28 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 29 of Set 8 | gurupi
# Processing Record 30 of Set 8 | kieta
# Processing Record 31 of Set 8 | mata
# Processing Record 32 of Set 8 | chirongui
# Processing Record 33 of Set 8 | arona
# Processing Record 34 of Set 8 | boende
# Processing Record 35 of Set 8 | kitgum
# Processing Record 36 of Set 8 | vila velha
# Processing Record 37 of Set 8 | san quintin
# Processing Record 38 of Set 8 | aguimes
# Processing Record 39 of Set 8 | naze
# Processing Record 40 of Set 8 | qabis
# City not found. Skipping...
# Processing Record 41 of Set 8 | malakal
# Processing Record 42 of Set 8 | afyonkarahisar
# Processing Record 43 of Set 8 | nicoya
# Processing Record 44 of Set 8 | hofn
# Processing Record 45 of Set 8 | grindavik
# Processing Record 46 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 8 | bilma
# Processing Record 48 of Set 8 | zamora
# Processing Record 49 of Set 8 | werda
# Processing Record 50 of Set 8 | manta
# Processing Record 1 of Set 9 | umm lajj
# Processing Record 2 of Set 9 | gamboula
# Processing Record 3 of Set 9 | vaitape
# Processing Record 4 of Set 9 | phan thiet
# Processing Record 5 of Set 9 | longonjo
# Processing Record 6 of Set 9 | kungurtug
# Processing Record 7 of Set 9 | mahon
# Processing Record 8 of Set 9 | lebu
# Processing Record 9 of Set 9 | jasidih
# Processing Record 10 of Set 9 | iskateley
# Processing Record 11 of Set 9 | mandal
# Processing Record 12 of Set 9 | zeerust
# Processing Record 13 of Set 9 | morgan city
# Processing Record 14 of Set 9 | esil
# Processing Record 15 of Set 9 | evensk
# Processing Record 16 of Set 9 | athens
# Processing Record 17 of Set 9 | esperance
# Processing Record 18 of Set 9 | jauja
# Processing Record 19 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 20 of Set 9 | escanaba
# Processing Record 21 of Set 9 | tateyama
# Processing Record 22 of Set 9 | faya
# Processing Record 23 of Set 9 | vrangel
# Processing Record 24 of Set 9 | dali
# Processing Record 25 of Set 9 | soe
# Processing Record 26 of Set 9 | ponta delgada
# Processing Record 27 of Set 9 | kondinskoye
# Processing Record 28 of Set 9 | kuala terengganu
# Processing Record 29 of Set 9 | baculin
# Processing Record 30 of Set 9 | ribeira brava
# Processing Record 31 of Set 9 | coolum beach
# Processing Record 32 of Set 9 | boca do acre
# Processing Record 33 of Set 9 | oyama
# Processing Record 34 of Set 9 | vanimo
# Processing Record 35 of Set 9 | blackfoot
# Processing Record 36 of Set 9 | nadvoitsy
# Processing Record 37 of Set 9 | anadyr
# Processing Record 38 of Set 9 | starokostyantyniv
# Processing Record 39 of Set 9 | usinsk
# Processing Record 40 of Set 9 | antalaha
# Processing Record 41 of Set 9 | tawang
# Processing Record 42 of Set 9 | nabire
# Processing Record 43 of Set 9 | skjervoy
# Processing Record 44 of Set 9 | umm kaddadah
# Processing Record 45 of Set 9 | komsomolskiy
# Processing Record 46 of Set 9 | aripuana
# Processing Record 47 of Set 9 | mabaruma
# Processing Record 48 of Set 9 | vila
# Processing Record 49 of Set 9 | gushikawa
# Processing Record 50 of Set 9 | pangnirtung
# Processing Record 1 of Set 10 | trelew
# Processing Record 2 of Set 10 | ambodifototra
# City not found. Skipping...
# Processing Record 3 of Set 10 | galgani
# City not found. Skipping...
# Processing Record 4 of Set 10 | tromso
# Processing Record 5 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 6 of Set 10 | isoka
# Processing Record 7 of Set 10 | montevideo
# Processing Record 8 of Set 10 | qeshm
# Processing Record 9 of Set 10 | constitucion
# Processing Record 10 of Set 10 | potgietersrus
# City not found. Skipping...
# Processing Record 11 of Set 10 | semey
# Processing Record 12 of Set 10 | north platte
# Processing Record 13 of Set 10 | graaff-reinet
# Processing Record 14 of Set 10 | yunjinghong
# City not found. Skipping...
# Processing Record 15 of Set 10 | mareeba
# Processing Record 16 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 17 of Set 10 | shingu
# Processing Record 18 of Set 10 | merauke
# Processing Record 19 of Set 10 | suluq
# Processing Record 20 of Set 10 | maracaibo
# Processing Record 21 of Set 10 | uniao da victoria
# City not found. Skipping...
# Processing Record 22 of Set 10 | beyneu
# Processing Record 23 of Set 10 | kalianget
# Processing Record 24 of Set 10 | igarka
# Processing Record 25 of Set 10 | hithadhoo
# Processing Record 26 of Set 10 | yerbogachen
# Processing Record 27 of Set 10 | razole
# Processing Record 28 of Set 10 | nanortalik
# Processing Record 29 of Set 10 | camana
# Processing Record 30 of Set 10 | russell
# Processing Record 31 of Set 10 | melito di porto salvo
# Processing Record 32 of Set 10 | padang
# Processing Record 33 of Set 10 | mvuma
# Processing Record 34 of Set 10 | tiznit
# Processing Record 35 of Set 10 | stromness
# Processing Record 36 of Set 10 | camacha
# Processing Record 37 of Set 10 | biak
# Processing Record 38 of Set 10 | tokzar
# City not found. Skipping...
# Processing Record 39 of Set 10 | coihaique
# Processing Record 40 of Set 10 | san cristobal
# Processing Record 41 of Set 10 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 42 of Set 10 | najran
# Processing Record 43 of Set 10 | erzin
# Processing Record 44 of Set 10 | taraz
# Processing Record 45 of Set 10 | baneh
# Processing Record 46 of Set 10 | bonavista
# Processing Record 47 of Set 10 | lugazi
# Processing Record 48 of Set 10 | palu
# Processing Record 49 of Set 10 | desaguadero
# Processing Record 50 of Set 10 | eyl
# Processing Record 1 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 2 of Set 11 | egvekinot
# Processing Record 3 of Set 11 | road town
# Processing Record 4 of Set 11 | leh
# Processing Record 5 of Set 11 | saint-pierre
# Processing Record 6 of Set 11 | kaseda
# Processing Record 7 of Set 11 | burnie
# Processing Record 8 of Set 11 | hamilton
# Processing Record 9 of Set 11 | singaraja
# Processing Record 10 of Set 11 | brae
# Processing Record 11 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 11 | sibolga
# Processing Record 13 of Set 11 | okha
# Processing Record 14 of Set 11 | hastings
# Processing Record 15 of Set 11 | noyabrsk
# Processing Record 16 of Set 11 | unye
# City not found. Skipping...
# Processing Record 17 of Set 11 | chimoio
# Processing Record 18 of Set 11 | marawi
# Processing Record 19 of Set 11 | kaoma
# Processing Record 20 of Set 11 | moose factory
# Processing Record 21 of Set 11 | bajah
# Processing Record 22 of Set 11 | sao sebastiao
# Processing Record 23 of Set 11 | jiroft
# City not found. Skipping...
# Processing Record 24 of Set 11 | urubicha
# Processing Record 25 of Set 11 | asau
# Processing Record 26 of Set 11 | san miguel
# Processing Record 27 of Set 11 | mitsamiouli
# Processing Record 28 of Set 11 | dingle
# Processing Record 29 of Set 11 | hambantota
# Processing Record 30 of Set 11 | fasa
# Processing Record 31 of Set 11 | sabancuy
# Processing Record 32 of Set 11 | tochio
# Processing Record 33 of Set 11 | montepuez
# Processing Record 34 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 35 of Set 11 | shibarghan
# City not found. Skipping...
# Processing Record 36 of Set 11 | pisco
# Processing Record 37 of Set 11 | langedijk
# Processing Record 38 of Set 11 | houma
# Processing Record 39 of Set 11 | sioux lookout
# Processing Record 40 of Set 11 | yongan
# Processing Record 41 of Set 11 | talcahuano
# Processing Record 42 of Set 11 | souillac
# Processing Record 43 of Set 11 | hailey
# Processing Record 44 of Set 11 | presidencia roque saenz pena
# Processing Record 45 of Set 11 | shihezi
# Processing Record 46 of Set 11 | nelson bay
# Processing Record 47 of Set 11 | loa janan
# Processing Record 48 of Set 11 | turukhansk
# Processing Record 49 of Set 11 | tezu
# Processing Record 50 of Set 11 | hualmay
# Processing Record 1 of Set 12 | walvis bay
# Processing Record 2 of Set 12 | warri
# Processing Record 3 of Set 12 | maumere
# Processing Record 4 of Set 12 | peno
# Processing Record 5 of Set 12 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 6 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 7 of Set 12 | fevralsk
# City not found. Skipping...
# Processing Record 8 of Set 12 | galiwinku
# City not found. Skipping...
# Processing Record 9 of Set 12 | paracatu
# Processing Record 10 of Set 12 | rumoi
# Processing Record 11 of Set 12 | alofi
# Processing Record 12 of Set 12 | te anau
# Processing Record 13 of Set 12 | mahebourg
# Processing Record 14 of Set 12 | la union
# Processing Record 15 of Set 12 | bikaner
# Processing Record 16 of Set 12 | kapuskasing
# Processing Record 17 of Set 12 | ambilobe
# Processing Record 18 of Set 12 | molchanovo
# Processing Record 19 of Set 12 | coahuayana
# Processing Record 20 of Set 12 | pathalgaon
# Processing Record 21 of Set 12 | yuanping
# Processing Record 22 of Set 12 | korop
# Processing Record 23 of Set 12 | santa isabel do rio negro
# Processing Record 24 of Set 12 | ewo
# Processing Record 25 of Set 12 | billings
# Processing Record 26 of Set 12 | morant bay
# Processing Record 27 of Set 12 | buraydah
# Processing Record 28 of Set 12 | utiel
# Processing Record 29 of Set 12 | malwan
# City not found. Skipping...
# Processing Record 30 of Set 12 | povorino
# Processing Record 31 of Set 12 | general salgado
# Processing Record 32 of Set 12 | djambala
# Processing Record 33 of Set 12 | hit
# Processing Record 34 of Set 12 | la rioja
# Processing Record 35 of Set 12 | matina
# Processing Record 36 of Set 12 | melilla
# Processing Record 37 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 38 of Set 12 | ardistan
# City not found. Skipping...
# Processing Record 39 of Set 12 | chavannes
# Processing Record 40 of Set 12 | kruisfontein
# Processing Record 41 of Set 12 | raga
# Processing Record 42 of Set 12 | ornskoldsvik
# Processing Record 43 of Set 12 | baruun-urt
# Processing Record 44 of Set 12 | fuerte olimpo
# Processing Record 45 of Set 12 | shenkursk
# Processing Record 46 of Set 12 | maningrida
# Processing Record 47 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 48 of Set 12 | puerto escondido
# Processing Record 49 of Set 12 | port blair
# Processing Record 50 of Set 12 | novoagansk
# Processing Record 1 of Set 13 | olafsvik
# Processing Record 2 of Set 13 | fort frances
# Processing Record 3 of Set 13 | olavarria
# Processing Record 4 of Set 13 | comodoro rivadavia
# Processing Record 5 of Set 13 | cayenne
# Processing Record 6 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 7 of Set 13 | prainha
# Processing Record 8 of Set 13 | almaznyy
# Processing Record 9 of Set 13 | salinas
# Processing Record 10 of Set 13 | aljezur
# Processing Record 11 of Set 13 | carauari
# Processing Record 12 of Set 13 | sibut
# Processing Record 13 of Set 13 | yabelo
# Processing Record 14 of Set 13 | juquia
# Processing Record 15 of Set 13 | diego de almagro
# Processing Record 16 of Set 13 | sorland
# Processing Record 17 of Set 13 | xam nua
# Processing Record 18 of Set 13 | sudislavl
# Processing Record 19 of Set 13 | pierre
# Processing Record 20 of Set 13 | cutervo
# Processing Record 21 of Set 13 | poum
# Processing Record 22 of Set 13 | chagoda
# Processing Record 23 of Set 13 | quincy
# Processing Record 24 of Set 13 | tukrah
# Processing Record 25 of Set 13 | calama
# Processing Record 26 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 27 of Set 13 | aitape
# Processing Record 28 of Set 13 | tinde
# Processing Record 29 of Set 13 | baykit
# Processing Record 30 of Set 13 | ivanjica
# Processing Record 31 of Set 13 | makakilo city
# Processing Record 32 of Set 13 | alyangula
# Processing Record 33 of Set 13 | gobo
# Processing Record 34 of Set 13 | paratebueno
# Processing Record 35 of Set 13 | farsund
# Processing Record 36 of Set 13 | belyy yar
# Processing Record 37 of Set 13 | arco
# Processing Record 38 of Set 13 | cerrito
# Processing Record 39 of Set 13 | ranfurly
# Processing Record 40 of Set 13 | oeiras
# Processing Record 41 of Set 13 | thiruvananthapuram
# Processing Record 42 of Set 13 | nhulunbuy
# Processing Record 43 of Set 13 | araouane
# Processing Record 44 of Set 13 | kodinsk
# Processing Record 45 of Set 13 | stokmarknes
# Processing Record 46 of Set 13 | nhlangano
# Processing Record 47 of Set 13 | aranos
# Processing Record 48 of Set 13 | quatre cocos
# Processing Record 49 of Set 13 | fethiye
# Processing Record 50 of Set 13 | dubuque
# Processing Record 1 of Set 14 | ixtapa
# Processing Record 2 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 3 of Set 14 | westpunt
# City not found. Skipping...
# Processing Record 4 of Set 14 | svetlaya
# Processing Record 5 of Set 14 | richmond
# Processing Record 6 of Set 14 | dzhusaly
# City not found. Skipping...
# Processing Record 7 of Set 14 | zhezkazgan
# Processing Record 8 of Set 14 | mnogovershinnyy
# Processing Record 9 of Set 14 | kamien pomorski
# Processing Record 10 of Set 14 | obeliai
# Processing Record 11 of Set 14 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 12 of Set 14 | chumikan
# Processing Record 13 of Set 14 | lithakia
# Processing Record 14 of Set 14 | nouadhibou
# Processing Record 15 of Set 14 | yhu
# Processing Record 16 of Set 14 | chernyshevskiy
# Processing Record 17 of Set 14 | abohar
# Processing Record 18 of Set 14 | kalikino
# Processing Record 19 of Set 14 | nyurba
# Processing Record 20 of Set 14 | abu kamal
# Processing Record 21 of Set 14 | meadow lake
# Processing Record 22 of Set 14 | saint andrews
# Processing Record 23 of Set 14 | dossor
# Processing Record 24 of Set 14 | zhaodong
# Processing Record 25 of Set 14 | karachi
# Processing Record 26 of Set 14 | valparaiso
# Processing Record 27 of Set 14 | portales
# Processing Record 28 of Set 14 | linares
# Processing Record 29 of Set 14 | buchanan
# Processing Record 30 of Set 14 | nyrob
# Processing Record 31 of Set 14 | la orilla
# Processing Record 32 of Set 14 | draguignan
# Processing Record 33 of Set 14 | sinnamary
# Processing Record 34 of Set 14 | atambua
# Processing Record 35 of Set 14 | tubruq
# City not found. Skipping...
# Processing Record 36 of Set 14 | voh
# Processing Record 37 of Set 14 | marrakesh
# Processing Record 38 of Set 14 | saint anthony
# Processing Record 39 of Set 14 | bud
# Processing Record 40 of Set 14 | la solana
# Processing Record 41 of Set 14 | waverly
# Processing Record 42 of Set 14 | pitea
# Processing Record 43 of Set 14 | shahpur
# Processing Record 44 of Set 14 | belaya gora
# Processing Record 45 of Set 14 | hirschaid
# Processing Record 46 of Set 14 | thohoyandou
# Processing Record 47 of Set 14 | edd
# Processing Record 48 of Set 14 | palauig
# Processing Record 49 of Set 14 | bayburt
# Processing Record 50 of Set 14 | katobu
# Processing Record 1 of Set 15 | lejanias
# Processing Record 2 of Set 15 | yarmouth
# Processing Record 3 of Set 15 | kiama
# Processing Record 4 of Set 15 | solnechnyy
# Processing Record 5 of Set 15 | atasu
# Processing Record 6 of Set 15 | ucluelet
# Processing Record 7 of Set 15 | viedma
# Processing Record 8 of Set 15 | sabanalarga
# Processing Record 9 of Set 15 | edgewater
# Processing Record 10 of Set 15 | les cayes
# Processing Record 11 of Set 15 | xinzhou
# Processing Record 12 of Set 15 | zaterechnyy
# Processing Record 13 of Set 15 | la asuncion
# Processing Record 14 of Set 15 | andros
# Processing Record 15 of Set 15 | kazalinsk
# City not found. Skipping...
# Processing Record 16 of Set 15 | meulaboh
# Processing Record 17 of Set 15 | mount isa
# Processing Record 18 of Set 15 | langsa
# Processing Record 19 of Set 15 | ozernovskiy
# Processing Record 20 of Set 15 | bela
# Processing Record 21 of Set 15 | bandarbeyla
# Processing Record 22 of Set 15 | daru
# Processing Record 23 of Set 15 | tongren
# Processing Record 24 of Set 15 | estelle
# Processing Record 25 of Set 15 | saint-georges
# Processing Record 26 of Set 15 | pucallpa
# Processing Record 27 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 28 of Set 15 | mae sai
# Processing Record 29 of Set 15 | yirol
# City not found. Skipping...
# Processing Record 30 of Set 15 | lokosovo
# Processing Record 31 of Set 15 | kyren
# Processing Record 32 of Set 15 | dukat
# Processing Record 33 of Set 15 | guasdualito
# Processing Record 34 of Set 15 | qaqortoq
# Processing Record 35 of Set 15 | hirara
# Processing Record 36 of Set 15 | artyom
# Processing Record 37 of Set 15 | arlit
# Processing Record 38 of Set 15 | kristiinankaupunki
# Processing Record 39 of Set 15 | kholodnyy
# Processing Record 40 of Set 15 | kwakoa
# Processing Record 41 of Set 15 | bulaevo
# Processing Record 42 of Set 15 | altona
# Processing Record 43 of Set 15 | ulcinj
# Processing Record 44 of Set 15 | watertown
# Processing Record 45 of Set 15 | gigmoto
# Processing Record 46 of Set 15 | takhtamukay
# Processing Record 47 of Set 15 | pimentel
# Processing Record 48 of Set 15 | zheleznodorozhnyy
# Processing Record 49 of Set 15 | skerries
# Processing Record 50 of Set 15 | hay river
# Processing Record 1 of Set 16 | monroe
# Processing Record 2 of Set 16 | klaksvik
# Processing Record 3 of Set 16 | bonfim
# Processing Record 4 of Set 16 | wiarton
# Processing Record 5 of Set 16 | norrkoping
# Processing Record 6 of Set 16 | ketchikan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Cape Town      ZA -33.9258   18.4232     69.12        83          20
# 1          Castro      BR -24.7911  -50.0119     70.88        81          14
# 2          Hobart      AU -42.8794  147.3294     61.27        81          75
# 3        Rantepao      ID  -2.9701  119.8978     66.90        97         100
# 4   Alice Springs      AU -23.7000  133.8833     58.55        77           0
# 5         Chapais      CA  49.7834  -74.8492     -6.02        80         100
# 6      Santa Rosa      PH  14.3122  121.1114     78.12        90         100
# 7            Hilo      US  19.7297 -155.0900     76.73        75          75
# 8         Ushuaia      AR -54.8000  -68.3000     40.66        81          75
# 9  Cabo San Lucas      MX  22.8909 -109.9124     85.30        57          75
#
#    Wind Speed Current Description
# 0       23.02          few clouds
# 1       11.12          few clouds
# 2       10.36          light rain
# 3        1.28     overcast clouds
# 4        5.75           clear sky
# 5        2.44     overcast clouds
# 6        6.85     overcast clouds
# 7        8.05       broken clouds
# 8       37.98          light rain
# 9        8.05       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
